# %%
import numpy as np
import matplotlib.pyplot as plt
from math import log

import matmacore as mm

# %%
mol = mm.Mol('sample_data/')
mol.csv('Qa-run_scr-paper-3.dat', dtype='str', skiprows=0)

# color = ['#a6cee3', '#fb9a99', '#53546c', '#e31a1c', '#1f78b4', '#1f78b4']

# %%
plot = mm.Plot()
plot.set_colors(['#a6cee3', '#fb9a99', '#53546c', '#e31a1c', '#1f78b4', '#1f78b4'])

plot.foo_plot(mol)
