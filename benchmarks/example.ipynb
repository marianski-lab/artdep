# %%
import MM_Util as mm

# %%
cp2k_test = mm.Mol('benchmarks/sample_data')
cp2k_test.cp2k(traj_file='cp2k_traj.xyz', colvar=[0, 2], timestep=0.5)

# %%
mm.Plot(cp2k_test.data).trajectory()
# Out:
# (<Figure size 1100x300 with 2 Axes>,
#  array([<Axes: xlabel='time (fs); stepsize = 0.5fs', ylabel='colvar'>,
#         <Axes: title={'center': 'average = 8.173'}, xlabel='structures'>],
#        dtype=object))

# %%
gromacs_test = mm.Mol('benchmarks/sample_data')
gromacs_test.gromacs(traj_file='gromacs.xvg')

# %%
mm.Plot(gromacs_test.data).trajectory()
# Out:
# (<Figure size 1100x300 with 2 Axes>,
#  array([<Axes: xlabel='time (fs); stepsize = 10.0fs', ylabel='colvar'>,
#         <Axes: title={'center': 'average = 0.727'}, xlabel='structures'>],
#        dtype=object))
