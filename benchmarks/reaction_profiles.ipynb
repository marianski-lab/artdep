# %%
import numpy as np
import sys
import os

sys.path.append('..')

# %%
from MM_Util.mol import *
from MM_Util.plot import *

# %%
pwd = os.path.abspath('')

wdir = os.path.join(pwd, 'sample_data','test_reaction')

print(wdir)
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/sample_data/test_reaction

# %%
mol_list = []


for d in os.listdir(wdir):
    valid_path = os.path.join(wdir, d)
    if os.path.isdir(valid_path):
        molecule = Mol(valid_path)
        molecule.gaussian()
        mol_list.append(molecule)
        print(d)
# Out:
# ts1
# product
# reactant
# int
# MeNH2
# methylacetamide

# %%
# reacts = Reaction.combiner([mol_list[2], mol_list[4]])
ts1 = mol_list[0]
int = mol_list[3]
# prods = Reaction.combiner([mol_list[1], mol_list[5]])

profile = [ts1, int]
labels = ['TS1', 'Int']

rxn = Reaction(profile, labels)

# %%
Plot.reaction_profile(Reaction, rxn, type = 'delta F')
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/../MM_Util/plot.py:154: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="lower left", frameon=False, fontsize=14)
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: ylabel='$\\Delta F$ (kcal $\\cdot$ mol${}^{-1}$)'>)
