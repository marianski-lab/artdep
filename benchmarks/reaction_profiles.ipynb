# %%
# %load_ext autoreload
# %autoreload 2

"""
The following lines of code are present for managing the working directory of the unit test, and should not be copied.
Please refer to the documentation to resolve any issues regarding directory management. 
"""
import os
import sys

sys.path.append('..')
pwd = os.path.abspath('')
wdir = os.path.join(pwd, 'sample_data','test_reaction')
print(wdir) 

"""Importing matmacore"""
import matmacore as mm
from matmacore.mol import *
from matmacore.plot import *
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/sample_data/test_reaction

# %%
"""
The inputs for plotting reaction coordinate diagrams should be structured as follows:

name = [
    '/path_to/a/directory', 
    '/path_to/another/directory',
    .
    .
    .
    .
    .
    'Coordinate label;]
"""


reacts = [
    os.path.join(wdir, 'MeNH2'), 
    os.path.join(wdir, 'reactant'),
    'R'  # Label
]

ts = [
    os.path.join(wdir, 'ts1'),
    'TS1'  # Label
]

prods = [
    os.path.join(wdir, 'methylacetamide'),
    os.path.join(wdir, 'product'),
    'P'  # Label
]

# Call the function
mol_list, mol_label = Reaction.create_mol_list(reacts, ts, prods)

labels = {
    'title': 'Test Reaction',
     'font': 'Arial',
     'title fontsize':16
     }

plot = mm.Plot()
plot.set_config(labels)
plot.cmap(color_num=1, map='bluyl')
plot.reaction_profile(mol_list, mol_label, type = 'F')
