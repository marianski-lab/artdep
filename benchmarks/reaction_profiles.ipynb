# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

sys.path.append('..')
pwd = os.path.abspath('')
wdir = os.path.join(pwd, 'sample_data','test_reaction')
print(wdir)
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/sample_data/test_reaction

# %%
import matmacore as mm
from matmacore.mol import *
from matmacore.plot import *
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/../matmacore/mol.py:104: SyntaxWarning: invalid escape sequence '\s'
#   elif flags['read_geom'] == True and re.search('^\s*.\d', line):
# /home/hillel/Code/style_guide/artdep/benchmarks/../matmacore/mol.py:129: SyntaxWarning: invalid escape sequence '\s'
#   elif flags['normal_mode'] == True and re.search('^\s*\d*\s*.\d*', line) and len(line.split()) > 3:
# /home/hillel/Code/style_guide/artdep/benchmarks/../matmacore/mol.py:148: SyntaxWarning: invalid escape sequence '\s'
#   elif flags['read_geom'] == True and re.search('^\s*.\d', line):
# /home/hillel/Code/style_guide/artdep/benchmarks/../matmacore/mol.py:161: SyntaxWarning: invalid escape sequence '\s'
#   elif flags['read_geom'] == True and re.search('^\s*.\d', line):
# /home/hillel/Code/style_guide/artdep/benchmarks/../matmacore/mol.py:171: SyntaxWarning: invalid escape sequence '\d'
#   elif flags['jcoup_flag'] == True and re.search('-?\d\.\d+[Dd][+\-]\d\d?', line):
# /home/hillel/Code/style_guide/artdep/benchmarks/../matmacore/mol.py:184: SyntaxWarning: invalid escape sequence '\s'
#   elif flags['read_geom'] == True and re.search('^\s*.\d', line):

# %%
reacts = [
    os.path.join(wdir, 'MeNH2'), 
    os.path.join(wdir, 'reactant'),
    'R'  # Label
]

ts = [
    os.path.join(wdir, 'ts1'),
    'TS1'  # Label
]

prods = [
    os.path.join(wdir, 'methylacetamide'),
    os.path.join(wdir, 'product'),
    'P'  # Label
]

# Call the function
mol_list, mol_label = Reaction.create_mol_list(reacts, ts, prods)


plot = mm.Plot()
plot.cmap(color_num=1, map='bluyl')
plot.reaction_profile(mol_list, mol_label, type = 'F')
