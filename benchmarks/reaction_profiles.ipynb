# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

sys.path.append('..')
pwd = os.path.abspath('')
wdir = os.path.join(pwd, 'sample_data','test_reaction')
print(wdir)
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/sample_data/test_reaction

# %%
import matmacore as mm
from matmacore.mol import *
from matmacore.plot import *

# %%
directories = [ 
    os.path.join(wdir, 'MeNH2'), 
    os.path.join(wdir, 'reactant'),
    os.path.join(wdir, 'ts1'),  
    os.path.join(wdir, 'int'), 
    os.path.join(wdir, 'ts2'),
    os.path.join(wdir, 'methylacetamide'),
    os.path.join(wdir, 'product')
]

combinations = [
    [directories[0], directories[1]],  
    [directories[2]],                  
    [directories[3]],                
    [directories[4]],             
    [directories[5], directories[6]]   
]


labels = ['R', 'TS1', 'Int', 'TS2', 'P']

# Call the function
mol_list, mol_label = Reaction.create_mol_list(directories, combinations, labels)


plot = mm.Plot()
plot.reaction_profile(mol_list, mol_label, type = 'F')
