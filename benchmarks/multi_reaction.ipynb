# %%
# %load_ext autoreload
# %autoreload 2

"""
The following lines of code are present for managing the working directory of the unit test, and should not be copied.
Please refer to the documentation to resolve any issues regarding directory management. 
"""

import os
import sys

sys.path.append('..')
pwd = os.path.abspath('')
wdir = os.path.join(pwd, 'sample_data','mult_reactions')
print(wdir) 

"""Importing matmacore"""
import matmacore as mm
from matmacore.mol import *
from matmacore.plot import *
# Out:
# /home/hillel/Code/style_guide/artdep/benchmarks/sample_data/mult_reactions

# %%
"""
The inputs for plotting multiple reactions should be structured as follows:

reactions = Reaction.create_reaction_list(
    ("Name of reaction 1",
     ['/path_to/reaction1/reactant1', '/path_to/reaction1/reactant2', ........... 'Coordinate Label 1'],
     ['/path_to/reaction1/output_file', 'Coordinate Label 2'],
     ['/path_to/reaction1/output_file', 'Coordinate Label 3'],
     ['/path_to/reaction1/product1', '/path_to/reaction1/product2', ......... 'Coordinate Label 4']),
    
    ("Name of reaction 2",
     .
     .
     .
     .
     )
)
"""


reactions = Reaction.create_reaction_list(
    ("x = CCH3",
     [os.path.join(wdir, 'cch3', 'reactant'), os.path.join(wdir, 'reactant_2'), 'R'],
     [os.path.join(wdir, 'cch3', 'ts1'), 'TS'],
     [os.path.join(wdir, 'cch3', 'int'), 'Int'],
     [os.path.join(wdir, 'cch3', 'product'), os.path.join(wdir, 'product_2'), 'P']),
    
    ("x = CCF3",
     [os.path.join(wdir, 'cf3', 'reactant'), os.path.join(wdir, 'reactant_2'), 'R'],
     [os.path.join(wdir, 'cf3', 'ts1'), 'TS'],
     [os.path.join(wdir, 'cf3', 'int'), 'Int'],
     [os.path.join(wdir, 'cf3', 'product'), os.path.join(wdir, 'product_2'), 'P']),

    ("x = CH2F",
     [os.path.join(wdir, 'ch2f', 'reactant'), os.path.join(wdir, 'reactant_2'), 'R'],
     [os.path.join(wdir, 'ch2f', 'ts1'), 'TS'],
     [os.path.join(wdir, 'ch2f', 'int'), 'Int'],
     [os.path.join(wdir, 'ch2f', 'product'), os.path.join(wdir, 'product_2'), 'P']),

    ("x = CHF2",
     [os.path.join(wdir, 'chf2', 'reactant'), os.path.join(wdir, 'reactant_2'), 'R'],
     [os.path.join(wdir, 'chf2', 'ts1'), 'TS'],
     [os.path.join(wdir, 'chf2', 'int'), 'Int'],
     [os.path.join(wdir, 'chf2', 'product'), os.path.join(wdir, 'product_2'), 'P']),

    ("x = OMe",
     [os.path.join(wdir, 'ome', 'reactant'), os.path.join(wdir, 'reactant_2'), 'R'],
     [os.path.join(wdir, 'ome', 'ts1'), 'TS'],
     [os.path.join(wdir, 'ome', 'int'), 'Int'],
     [os.path.join(wdir, 'ome', 'product'), os.path.join(wdir, 'product_2'), 'P']),
)

labels = {
    'title': 'Test: Multiple Reactions',
     'font': 'Arial',
     'title fontsize':16
     }

plot = mm.Plot()
plot.cmap(color_num=len(reactions)) 
plot.set_config(labels)
plot.multi_profile(reactions, type='E', units='kcal')
