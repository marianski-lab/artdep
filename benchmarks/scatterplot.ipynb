# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import random
from MM_Util.plot import *

np.random.seed(42069)
x = np.linspace(-100, 100, 120)

y1 = np.random.randint(0, 10, len(x))
y1 = [y+ np.random.rand() for y in y1]
y2 = np.random.randint(0, 10, len(x))
y2 = [y + np.random.rand() for y in y2]


data = np.column_stack((x, y1, y2))
labels = ["Scatter Plot", "X-axis", "Y-axis"]
desc = ["Dataset 1", "Dataset 2"]

scatter_plot = Plot(data, labels=labels, desc=desc, x_extend=80, y_extend=0)

scatter_plot.cmap(color_num=2, offset=0.1, map='devon')
scatter_plot.scatter()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# -150.0 150.0 0.0 10.0
