# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from MM_Util.plot import *

np.random.seed(42069)
x = np.linspace(0, 10, 50)
y1 = 2 * x + np.random.normal(0, 2, size=x.shape)
y2 = -1.5 * x + np.random.normal(0, 2, size=x.shape)

data = np.column_stack((x, y1, y2))
labels = ["Scatter Plot", "X-axis", "Y-axis"]
desc = ["Dataset 1", "Dataset 2"]

scatter_plot = Plot(data, labels=labels, desc=desc)

scatter_plot.cmap(color_num=2, offset=0.2, map='acton')
scatter_plot.scatter(r2=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
